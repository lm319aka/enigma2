# %%
import numpy as np
rng = np.random.default_rng(seed=1701)

# %%
example_data = np.arange(256, dtype=np.int16)

# %%
def create_rotor(top=256):
    new_rotor = np.arange(top, dtype=np.int16)
    rng.shuffle(new_rotor)
    return new_rotor
# Out:
# array([  9,  56,  87, 108,  54,   4, 146, 147,  19, 215,  18, 131,  58,
#        218, 105,  97,  49,  59, 151, 171, 128,  84,  89, 190, 204,  29,
#        230,  21, 203, 121, 222,  40,  60,  11, 211, 226, 104, 241,  10,
#         14, 206,   7, 172,  17, 118, 242, 220, 231, 254, 179,  32, 159,
#        166, 197, 233, 102, 140, 227,  28, 133,  71,  35,  12, 143, 221,
#        199, 181, 122, 185, 178,  63, 177, 119, 164, 219, 168,  77, 175,
#        188, 202,  34,  37, 106, 229, 182,  96, 129,  15,  50,   8,   5,
#        113, 234, 126, 253,  41, 132, 228, 173, 136, 116, 125, 127, 245,
#        248, 101, 160,  38, 239, 217, 134,  25, 111, 252,  51, 124, 189,
#        107, 213, 209,  36,  26,  16,  47,  44,  42, 187,  23,  70, 139,
#        250, 237,  82, 163,  80,  53, 156, 243,  48,  20, 157, 100, 176,
#         64,  45,  43, 169, 110, 149,  98,  95, 186, 137,  94, 249,  30,
#        109,   2,  74,  46, 207,  88, 198, 153,  22,  52, 225,  69, 114,
# ...
